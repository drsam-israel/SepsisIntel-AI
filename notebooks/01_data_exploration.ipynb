# %%
import pandas as pd
import numpy as np
import glob

print("Clinical Sepsis Intelligence System Ready")
# Out:
# Clinical Sepsis Intelligence System Ready

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\DR SAMUEL ISRAEL\Desktop\AI projects folder\Clinical_Sepsis_Intelligence_System\notebooks

# %%
import glob

all_files = glob.glob("../data/**/*.psv", recursive=True)

print("Total Patient Files:", len(all_files))
# Out:
# Total Patient Files: 0

# %%
all_files[:5]
# Out:
# []

# %%
import glob

all_files = glob.glob("../data/**/*.psv", recursive=True)

print("Total Patient Files:", len(all_files))
# Out:
# Total Patient Files: 40336
